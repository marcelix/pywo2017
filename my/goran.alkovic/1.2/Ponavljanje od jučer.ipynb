# %%
d = {1:'jedan', 'a':'slovo A'}

# List comprehension
L = [2*i for i in range(1, 11)]

# %%
d2 = {k:str(k) for k in L}
d2
# Out:
# {2: '2',
#  4: '4',
#  6: '6',
#  8: '8',
#  10: '10',
#  12: '12',
#  14: '14',
#  16: '16',
#  18: '18',
#  20: '20'}

# %% [markdown]
# Kako se iterira po ovim strukturama?

# %%
for x in L:
    y = x ** 2
    print(y)
# Out:
# 4
# 16
# 36
# 64
# 100
# 144
# 196
# 256
# 324
# 400

# %%
i = 0
for i, x in enumerate(L):
    i = i + 1
    print(i, ".", x)
# Out:
# 1 . 2
# 2 . 4
# 3 . 6
# 4 . 8
# 5 . 10
# 6 . 12
# 7 . 14
# 8 . 16
# 9 . 18
# 10 . 20

# %%
for k, v in d.items():
    print(k, " ", v)
# Out:
# 1   jedan
# a   slovo A

# %% [markdown]
# ## Još malo o Jupyteru (ipython)

# %%
# escaping
L = !dir/s
L
# Out:
# [' Volume in drive C has no label.',
#  ' Volume Serial Number is 289C-D677',
#  '',
#  ' Directory of C:\\Users\\goran\\OneDrive\\FOI_docs\\Radionica Napredno programiranje u Pythonu\\S02',
#  '',
#  '10.07.2017.  08:29    <DIR>          .',
#  '10.07.2017.  08:29    <DIR>          ..',
#  '10.07.2017.  08:21    <DIR>          .ipynb_checkpoints',
#  '10.07.2017.  08:29             3.962 Untitled.ipynb',
#  '               1 File(s)          3.962 bytes',
#  '',
#  ' Directory of C:\\Users\\goran\\OneDrive\\FOI_docs\\Radionica Napredno programiranje u Pythonu\\S02\\.ipynb_checkpoints',
#  '',
#  '10.07.2017.  08:21    <DIR>          .',
#  '10.07.2017.  08:21    <DIR>          ..',
#  '10.07.2017.  08:21                72 Untitled-checkpoint.ipynb',
#  '               1 File(s)             72 bytes',
#  '',
#  '     Total Files Listed:',
#  '               2 File(s)          4.034 bytes',
#  '               5 Dir(s)  136.313.008.128 bytes free']

# %%
notebook_filename = "Untitled.ipynb"
# !cat $notebook_filename

# %% [markdown]
# ## Magija

# %%
w%lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%cmd  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.

# %%
# %%writefile "fja.py"
#
# def f(a, b):
#     pass
# Out:
# Overwriting fja.py

# %%
# %load "./fja.py"

def f(a, b):
    pass

# %%
# %load "fja.py"

def f(a, b):
    pass

# %%
run hello_world.ipynb
# Out:
# Hello, world

# %% [markdown]
# Sve varijable koje smo definirali

# %%
whos
# Out:
# Variable            Type        Data/Info
# -----------------------------------------
# L                   SList       [' Volume in drive C has <...>.313.008.128 bytes free']
# d                   dict        n=2
# d2                  dict        n=10
# f                   function    <function f at 0x00000261113A9C80>
# i                   int         10
# k                   str         a
# notebook_filename   str         Untitled.ipynb
# v                   str         slovo A
# x                   int         20
# y                   int         400

# %% [markdown]
# HTML/JS

# %%
# %%html
#
# Javascript
# Out:
# Javascript

# %%
locals()
# Out:
# {'In': ['',
#   'd2 = {k:str(k) for k in L}\nd2',
#   'd2 = {k:str(k) for k in L}\nd2',
#   "d = {l:'jedan', 'a':'slovo A'}\n\n# List comprehension\nL = [2*i for i in range(1, 11)]",
#   "d = {'l:'jedan', 'a':'slovo A'}\n\n# List comprehension\nL = [2*i for i in range(1, 11)]",
#   "d = {l:'jedan', a:'slovo A'}\n\n# List comprehension\nL = [2*i for i in range(1, 11)]",
#   'd2 = {k:str(k) for k in L}\nd2',
#   "d = {1:'jedan', a:'slovo A'}\n\n# List comprehension\nL = [2*i for i in range(1, 11)]",
#   "d = {1:'jedan', 'a':'slovo A'}\n\n# List comprehension\nL = [2*i for i in range(1, 11)]",
#   'd2 = {k:str(k) for k in L}\nd2',
#   'd2 = {k:str(k) for k in L}\nd2',
#   'for x in L:\n    y = x ** 2\n    print(y)',
#   'for x in L:\n    y = x ** 2\n    print(y)',
#   'i = 0\nfor x in L:\n    i = i + 1\n    print(i, ".", x)',
#   'i = 0\nfor x in enumerate(L):\n    i = i + 1\n    print(i, ".", x)',
#   'i = 0\nfor i,x in enumerate(L):\n    i = i + 1\n    print(i, ".", x)',
#   'i = 0\nfor i, x in enumerate(L):\n    i = i + 1\n    print(i, ".", x)',
#   'i = 0\nfor i, x in enumerate(L):\n    i = i + 1\n    print(i, ".", x)',
#   'd',
#   'for k in d:\n    print(k)',
#   'for k,v in d:\n    print(k, " ", v)',
#   'for k,d(k() in d:\n    print(k, " ", v)',
#   'for k,d(k) in d:\n    print(k, " ", d(k))',
#   'for k,d[k] in d.values():\n    print(k, " ", d[k]',
#   'for v in d.items():\n    print(v)',
#   'for k, v in d.items():\n    print(k, " ", v)',
#   'for k, v in d.items():\n    print(k, " ", v)',
#   "get_ipython().system('ls')",
#   "get_ipython().system('dir/s')",
#   "# escaping\nget_ipython().system('dir/s')",
#   "# escaping\nL = get_ipython().getoutput('dir/s')",
#   "# escaping\nL = get_ipython().getoutput('dir/s')\nL",
#   "# escaping\nL = get_ipython().getoutput('dir/s')\nL",
#   'notebook_filename = "Untitled.ipynb"\nnotebook_filename',
#   'notebook_filename = "Untitled.ipynb"\nget_ipython().system(\'edit $notebook_filename\')',
#   'notebook_filename = "Untitled.ipynb"\n# !cat $notebook_filename',
#   'notebook_filename = "Untitled.ipynb"\n# !cat $notebook_filename\nget_ipython().system(\'iexplore\')',
#   'notebook_filename = "Untitled.ipynb"\n# !cat $notebook_filename\nget_ipython().system(\'iexplore.exe\')',
#   'notebook_filename = "Untitled.ipynb"\n# !cat $notebook_filename',
#   "get_ipython().magic('lsmagic')",
#   "get_ipython().magic('lsmagic')",
#   "get_ipython().magic('lsmagic ')",
#   'get_ipython().run_cell_magic(\'writefile\', \'"fja.py"\', \'\\ndef f(a, b):\\n    pass\')',
#   'writefile "fja.py"\n\ndef f(a, b):\n    pass',
#   'get_ipython().magic(\'writefile "fja.py"\')\n\ndef f(a, b):\n    pass',
#   'get_ipython().run_cell_magic(\'writefile\', \'"fja.py"\', \'\\ndef f(a, b):\\n    pass\')',
#   '# Spremanje u file\n%%writefile "fja.py"\n\ndef f(a, b):\n    pass',
#   '# Spremanje u file\n\n%%writefile "fja.py"\n\ndef f(a, b):\n    pass',
#   'loadfile "fja.py"',
#   'get_ipython().run_cell_magic(\'writefile\', \'"fja.py"\', \'\\ndef f(a, b):\\n    pass\')',
#   'loadfile "fja.py"',
#   'loadfile "/fja.py"',
#   'loadfile "./fja.py"',
#   'get_ipython().magic(\'loadpy "./fja.py"\')',
#   '# %load "./fja.py"\n\ndef f(a, b):\n    pass',
#   "get_ipython().magic('run hello_world.ipynb')",
#   '# %load "./fja.py"\n\ndef f(a, b):\n    pass',
#   'get_ipython().magic(\'loadpy "fja.py"\')',
#   "get_ipython().magic('run hello_world.ipynb')",
#   "get_ipython().magic('whos ')",
#   'whos\n#Sve varijable koje smo definirali',
#   "get_ipython().magic('whos ')",
#   "get_ipython().run_cell_magic('html', '', '\\nJavascript')",
#   "get_ipython().run_cell_magic('html', '', '\\nJavascript')",
#   'locals()',
#   'locals()'],
#  'L': [' Volume in drive C has no label.',
#   ' Volume Serial Number is 289C-D677',
#   '',
#   ' Directory of C:\\Users\\goran\\OneDrive\\FOI_docs\\Radionica Napredno programiranje u Pythonu\\S02',
#   '',
#   '10.07.2017.  08:29    <DIR>          .',
#   '10.07.2017.  08:29    <DIR>          ..',
#   '10.07.2017.  08:21    <DIR>          .ipynb_checkpoints',
#   '10.07.2017.  08:29             3.962 Untitled.ipynb',
#   '               1 File(s)          3.962 bytes',
#   '',
#   ' Directory of C:\\Users\\goran\\OneDrive\\FOI_docs\\Radionica Napredno programiranje u Pythonu\\S02\\.ipynb_checkpoints',
#   '',
#   '10.07.2017.  08:21    <DIR>          .',
#   '10.07.2017.  08:21    <DIR>          ..',
#   '10.07.2017.  08:21                72 Untitled-checkpoint.ipynb',
#   '               1 File(s)             72 bytes',
#   '',
#   '     Total Files Listed:',
#   '               2 File(s)          4.034 bytes',
#   '               5 Dir(s)  136.313.008.128 bytes free'],
#  'Out': {9: {2: '2',
#    4: '4',
#    6: '6',
#    8: '8',
#    10: '10',
#    12: '12',
#    14: '14',
#    16: '16',
#    18: '18',
#    20: '20'},
#   10: {2: '2',
#    4: '4',
#    6: '6',
#    8: '8',
#    10: '10',
#    12: '12',
#    14: '14',
#    16: '16',
#    18: '18',
#    20: '20'},
#   18: {1: 'jedan', 'a': 'slovo A'},
#   31: [' Volume in drive C has no label.',
#    ' Volume Serial Number is 289C-D677',
#    '',
#    ' Directory of C:\\Users\\goran\\OneDrive\\FOI_docs\\Radionica Napredno programiranje u Pythonu\\S02',
#    '',
#    '10.07.2017.  08:29    <DIR>          .',
#    '10.07.2017.  08:29    <DIR>          ..',
#    '10.07.2017.  08:21    <DIR>          .ipynb_checkpoints',
#    '10.07.2017.  08:29             3.962 Untitled.ipynb',
#    '               1 File(s)          3.962 bytes',
#    '',
#    ' Directory of C:\\Users\\goran\\OneDrive\\FOI_docs\\Radionica Napredno programiranje u Pythonu\\S02\\.ipynb_checkpoints',
#    '',
#    '10.07.2017.  08:21    <DIR>          .',
#    '10.07.2017.  08:21    <DIR>          ..',
#    '10.07.2017.  08:21                72 Untitled-checkpoint.ipynb',
#    '               1 File(s)             72 bytes',
#    '',
#    '     Total Files Listed:',
#    '               2 File(s)          4.034 bytes',
#    '               5 Dir(s)  136.313.028.608 bytes free'],
#   32: [' Volume in drive C has no label.',
#    ' Volume Serial Number is 289C-D677',
#    '',
#    ' Directory of C:\\Users\\goran\\OneDrive\\FOI_docs\\Radionica Napredno programiranje u Pythonu\\S02',
#    '',
#    '10.07.2017.  08:29    <DIR>          .',
#    '10.07.2017.  08:29    <DIR>          ..',
#    '10.07.2017.  08:21    <DIR>          .ipynb_checkpoints',
#    '10.07.2017.  08:29             3.962 Untitled.ipynb',
#    '               1 File(s)          3.962 bytes',
#    '',
#    ' Directory of C:\\Users\\goran\\OneDrive\\FOI_docs\\Radionica Napredno programiranje u Pythonu\\S02\\.ipynb_checkpoints',
#    '',
#    '10.07.2017.  08:21    <DIR>          .',
#    '10.07.2017.  08:21    <DIR>          ..',
#    '10.07.2017.  08:21                72 Untitled-checkpoint.ipynb',
#    '               1 File(s)             72 bytes',
#    '',
#    '     Total Files Listed:',
#    '               2 File(s)          4.034 bytes',
#    '               5 Dir(s)  136.313.008.128 bytes free'],
#   33: 'Untitled.ipynb',
#   39: Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%cmd  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.,
#   40: Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%cmd  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.,
#   41: Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%cmd  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.,
#   64: {...}},
#  '_': {...},
#  '_10': {2: '2',
#   4: '4',
#   6: '6',
#   8: '8',
#   10: '10',
#   12: '12',
#   14: '14',
#   16: '16',
#   18: '18',
#   20: '20'},
#  '_18': {1: 'jedan', 'a': 'slovo A'},
#  '_31': [' Volume in drive C has no label.',
#   ' Volume Serial Number is 289C-D677',
#   '',
#   ' Directory of C:\\Users\\goran\\OneDrive\\FOI_docs\\Radionica Napredno programiranje u Pythonu\\S02',
#   '',
#   '10.07.2017.  08:29    <DIR>          .',
#   '10.07.2017.  08:29    <DIR>          ..',
#   '10.07.2017.  08:21    <DIR>          .ipynb_checkpoints',
#   '10.07.2017.  08:29             3.962 Untitled.ipynb',
#   '               1 File(s)          3.962 bytes',
#   '',
#   ' Directory of C:\\Users\\goran\\OneDrive\\FOI_docs\\Radionica Napredno programiranje u Pythonu\\S02\\.ipynb_checkpoints',
#   '',
#   '10.07.2017.  08:21    <DIR>          .',
#   '10.07.2017.  08:21    <DIR>          ..',
#   '10.07.2017.  08:21                72 Untitled-checkpoint.ipynb',
#   '               1 File(s)             72 bytes',
#   '',
#   '     Total Files Listed:',
#   '               2 File(s)          4.034 bytes',
#   '               5 Dir(s)  136.313.028.608 bytes free'],
#  '_32': [' Volume in drive C has no label.',
#   ' Volume Serial Number is 289C-D677',
#   '',
#   ' Directory of C:\\Users\\goran\\OneDrive\\FOI_docs\\Radionica Napredno programiranje u Pythonu\\S02',
#   '',
#   '10.07.2017.  08:29    <DIR>          .',
#   '10.07.2017.  08:29    <DIR>          ..',
#   '10.07.2017.  08:21    <DIR>          .ipynb_checkpoints',
#   '10.07.2017.  08:29             3.962 Untitled.ipynb',
#   '               1 File(s)          3.962 bytes',
#   '',
#   ' Directory of C:\\Users\\goran\\OneDrive\\FOI_docs\\Radionica Napredno programiranje u Pythonu\\S02\\.ipynb_checkpoints',
#   '',
#   '10.07.2017.  08:21    <DIR>          .',
#   '10.07.2017.  08:21    <DIR>          ..',
#   '10.07.2017.  08:21                72 Untitled-checkpoint.ipynb',
#   '               1 File(s)             72 bytes',
#   '',
#   '     Total Files Listed:',
#   '               2 File(s)          4.034 bytes',
#   '               5 Dir(s)  136.313.008.128 bytes free'],
#  '_33': 'Untitled.ipynb',
#  '_39': Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%cmd  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.,
#  '_40': Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%cmd  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.,
#  '_41': Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%cmd  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.,
#  '_64': {...},
#  '_9': {2: '2',
#   4: '4',
#   6: '6',
#   8: '8',
#   10: '10',
#   12: '12',
#   14: '14',
#   16: '16',
#   18: '18',
#   20: '20'},
#  '__': Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%cmd  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.,
#  '___': Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%cmd  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__loader__': None,
#  '__name__': '__main__',
#  '__package__': None,
#  '__spec__': None,
#  '_dh': ['C:\\Users\\goran\\OneDrive\\FOI_docs\\Radionica Napredno programiranje u Pythonu\\S02'],
#  '_exit_code': 1,
#  '_i': 'locals()',
#  '_i1': 'd2 = {k:str(k) for k in L}\nd2',
#  '_i10': 'd2 = {k:str(k) for k in L}\nd2',
#  '_i11': 'for x in L:\n    y = x ** 2\n    print(y)',
#  '_i12': 'for x in L:\n    y = x ** 2\n    print(y)',
#  '_i13': 'i = 0\nfor x in L:\n    i = i + 1\n    print(i, ".", x)',
#  '_i14': 'i = 0\nfor x in enumerate(L):\n    i = i + 1\n    print(i, ".", x)',
#  '_i15': 'i = 0\nfor i,x in enumerate(L):\n    i = i + 1\n    print(i, ".", x)',
#  '_i16': 'i = 0\nfor i, x in enumerate(L):\n    i = i + 1\n    print(i, ".", x)',
#  '_i17': 'i = 0\nfor i, x in enumerate(L):\n    i = i + 1\n    print(i, ".", x)',
#  '_i18': 'd',
#  '_i19': 'for k in d:\n    print(k)',
#  '_i2': 'd2 = {k:str(k) for k in L}\nd2',
#  '_i20': 'for k,v in d:\n    print(k, " ", v)',
#  '_i21': 'for k,d(k() in d:\n    print(k, " ", v)',
#  '_i22': 'for k,d(k) in d:\n    print(k, " ", d(k))',
#  '_i23': 'for k,d[k] in d.values():\n    print(k, " ", d[k]',
#  '_i24': 'for v in d.items():\n    print(v)',
#  '_i25': 'for k, v in d.items():\n    print(k, " ", v)',
#  '_i26': 'for k, v in d.items():\n    print(k, " ", v)',
#  '_i27': '!ls',
#  '_i28': '!dir/s',
#  '_i29': '# escaping\n!dir/s',
#  '_i3': "d = {l:'jedan', 'a':'slovo A'}\n\n# List comprehension\nL = [2*i for i in range(1, 11)]",
#  '_i30': '# escaping\nL = !dir/s',
#  '_i31': '# escaping\nL = !dir/s\nL',
#  '_i32': '# escaping\nL = !dir/s\nL',
#  '_i33': 'notebook_filename = "Untitled.ipynb"\nnotebook_filename',
#  '_i34': 'notebook_filename = "Untitled.ipynb"\n!edit $notebook_filename',
#  '_i35': 'notebook_filename = "Untitled.ipynb"\n# !cat $notebook_filename',
#  '_i36': 'notebook_filename = "Untitled.ipynb"\n# !cat $notebook_filename\n!iexplore',
#  '_i37': 'notebook_filename = "Untitled.ipynb"\n# !cat $notebook_filename\n!iexplore.exe',
#  '_i38': 'notebook_filename = "Untitled.ipynb"\n# !cat $notebook_filename',
#  '_i39': '%lsmagic',
#  '_i4': "d = {'l:'jedan', 'a':'slovo A'}\n\n# List comprehension\nL = [2*i for i in range(1, 11)]",
#  '_i40': '%lsmagic',
#  '_i41': 'lsmagic',
#  '_i42': '%%writefile "fja.py"\n\ndef f(a, b):\n    pass',
#  '_i43': 'writefile "fja.py"\n\ndef f(a, b):\n    pass',
#  '_i44': '%writefile "fja.py"\n\ndef f(a, b):\n    pass',
#  '_i45': '%%writefile "fja.py"\n\ndef f(a, b):\n    pass',
#  '_i46': '# Spremanje u file\n%%writefile "fja.py"\n\ndef f(a, b):\n    pass',
#  '_i47': '# Spremanje u file\n\n%%writefile "fja.py"\n\ndef f(a, b):\n    pass',
#  '_i48': 'loadfile "fja.py"',
#  '_i49': '%%writefile "fja.py"\n\ndef f(a, b):\n    pass',
#  '_i5': "d = {l:'jedan', a:'slovo A'}\n\n# List comprehension\nL = [2*i for i in range(1, 11)]",
#  '_i50': 'loadfile "fja.py"',
#  '_i51': 'loadfile "/fja.py"',
#  '_i52': 'loadfile "./fja.py"',
#  '_i53': 'loadpy "./fja.py"',
#  '_i54': '# %load "./fja.py"\n\ndef f(a, b):\n    pass',
#  '_i55': 'run hello_world.ipynb',
#  '_i56': '# %load "./fja.py"\n\ndef f(a, b):\n    pass',
#  '_i57': 'loadpy "fja.py"',
#  '_i58': 'run hello_world.ipynb',
#  '_i59': 'whos',
#  '_i6': 'd2 = {k:str(k) for k in L}\nd2',
#  '_i60': 'whos\n#Sve varijable koje smo definirali',
#  '_i61': 'whos',
#  '_i62': '%%html\n\nJavascript',
#  '_i63': '%%html\n\nJavascript',
#  '_i64': 'locals()',
#  '_i65': 'locals()',
#  '_i7': "d = {1:'jedan', a:'slovo A'}\n\n# List comprehension\nL = [2*i for i in range(1, 11)]",
#  '_i8': "d = {1:'jedan', 'a':'slovo A'}\n\n# List comprehension\nL = [2*i for i in range(1, 11)]",
#  '_i9': 'd2 = {k:str(k) for k in L}\nd2',
#  '_ih': ['',
#   'd2 = {k:str(k) for k in L}\nd2',
#   'd2 = {k:str(k) for k in L}\nd2',
#   "d = {l:'jedan', 'a':'slovo A'}\n\n# List comprehension\nL = [2*i for i in range(1, 11)]",
#   "d = {'l:'jedan', 'a':'slovo A'}\n\n# List comprehension\nL = [2*i for i in range(1, 11)]",
#   "d = {l:'jedan', a:'slovo A'}\n\n# List comprehension\nL = [2*i for i in range(1, 11)]",
#   'd2 = {k:str(k) for k in L}\nd2',
#   "d = {1:'jedan', a:'slovo A'}\n\n# List comprehension\nL = [2*i for i in range(1, 11)]",
#   "d = {1:'jedan', 'a':'slovo A'}\n\n# List comprehension\nL = [2*i for i in range(1, 11)]",
#   'd2 = {k:str(k) for k in L}\nd2',
#   'd2 = {k:str(k) for k in L}\nd2',
#   'for x in L:\n    y = x ** 2\n    print(y)',
#   'for x in L:\n    y = x ** 2\n    print(y)',
#   'i = 0\nfor x in L:\n    i = i + 1\n    print(i, ".", x)',
#   'i = 0\nfor x in enumerate(L):\n    i = i + 1\n    print(i, ".", x)',
#   'i = 0\nfor i,x in enumerate(L):\n    i = i + 1\n    print(i, ".", x)',
#   'i = 0\nfor i, x in enumerate(L):\n    i = i + 1\n    print(i, ".", x)',
#   'i = 0\nfor i, x in enumerate(L):\n    i = i + 1\n    print(i, ".", x)',
#   'd',
#   'for k in d:\n    print(k)',
#   'for k,v in d:\n    print(k, " ", v)',
#   'for k,d(k() in d:\n    print(k, " ", v)',
#   'for k,d(k) in d:\n    print(k, " ", d(k))',
#   'for k,d[k] in d.values():\n    print(k, " ", d[k]',
#   'for v in d.items():\n    print(v)',
#   'for k, v in d.items():\n    print(k, " ", v)',
#   'for k, v in d.items():\n    print(k, " ", v)',
#   "get_ipython().system('ls')",
#   "get_ipython().system('dir/s')",
#   "# escaping\nget_ipython().system('dir/s')",
#   "# escaping\nL = get_ipython().getoutput('dir/s')",
#   "# escaping\nL = get_ipython().getoutput('dir/s')\nL",
#   "# escaping\nL = get_ipython().getoutput('dir/s')\nL",
#   'notebook_filename = "Untitled.ipynb"\nnotebook_filename',
#   'notebook_filename = "Untitled.ipynb"\nget_ipython().system(\'edit $notebook_filename\')',
#   'notebook_filename = "Untitled.ipynb"\n# !cat $notebook_filename',
#   'notebook_filename = "Untitled.ipynb"\n# !cat $notebook_filename\nget_ipython().system(\'iexplore\')',
#   'notebook_filename = "Untitled.ipynb"\n# !cat $notebook_filename\nget_ipython().system(\'iexplore.exe\')',
#   'notebook_filename = "Untitled.ipynb"\n# !cat $notebook_filename',
#   "get_ipython().magic('lsmagic')",
#   "get_ipython().magic('lsmagic')",
#   "get_ipython().magic('lsmagic ')",
#   'get_ipython().run_cell_magic(\'writefile\', \'"fja.py"\', \'\\ndef f(a, b):\\n    pass\')',
#   'writefile "fja.py"\n\ndef f(a, b):\n    pass',
#   'get_ipython().magic(\'writefile "fja.py"\')\n\ndef f(a, b):\n    pass',
#   'get_ipython().run_cell_magic(\'writefile\', \'"fja.py"\', \'\\ndef f(a, b):\\n    pass\')',
#   '# Spremanje u file\n%%writefile "fja.py"\n\ndef f(a, b):\n    pass',
#   '# Spremanje u file\n\n%%writefile "fja.py"\n\ndef f(a, b):\n    pass',
#   'loadfile "fja.py"',
#   'get_ipython().run_cell_magic(\'writefile\', \'"fja.py"\', \'\\ndef f(a, b):\\n    pass\')',
#   'loadfile "fja.py"',
#   'loadfile "/fja.py"',
#   'loadfile "./fja.py"',
#   'get_ipython().magic(\'loadpy "./fja.py"\')',
#   '# %load "./fja.py"\n\ndef f(a, b):\n    pass',
#   "get_ipython().magic('run hello_world.ipynb')",
#   '# %load "./fja.py"\n\ndef f(a, b):\n    pass',
#   'get_ipython().magic(\'loadpy "fja.py"\')',
#   "get_ipython().magic('run hello_world.ipynb')",
#   "get_ipython().magic('whos ')",
#   'whos\n#Sve varijable koje smo definirali',
#   "get_ipython().magic('whos ')",
#   "get_ipython().run_cell_magic('html', '', '\\nJavascript')",
#   "get_ipython().run_cell_magic('html', '', '\\nJavascript')",
#   'locals()',
#   'locals()'],
#  '_ii': '%%html\n\nJavascript',
#  '_iii': '%%html\n\nJavascript',
#  '_oh': {9: {2: '2',
#    4: '4',
#    6: '6',
#    8: '8',
#    10: '10',
#    12: '12',
#    14: '14',
#    16: '16',
#    18: '18',
#    20: '20'},
#   10: {2: '2',
#    4: '4',
#    6: '6',
#    8: '8',
#    10: '10',
#    12: '12',
#    14: '14',
#    16: '16',
#    18: '18',
#    20: '20'},
#   18: {1: 'jedan', 'a': 'slovo A'},
#   31: [' Volume in drive C has no label.',
#    ' Volume Serial Number is 289C-D677',
#    '',
#    ' Directory of C:\\Users\\goran\\OneDrive\\FOI_docs\\Radionica Napredno programiranje u Pythonu\\S02',
#    '',
#    '10.07.2017.  08:29    <DIR>          .',
#    '10.07.2017.  08:29    <DIR>          ..',
#    '10.07.2017.  08:21    <DIR>          .ipynb_checkpoints',
#    '10.07.2017.  08:29             3.962 Untitled.ipynb',
#    '               1 File(s)          3.962 bytes',
#    '',
#    ' Directory of C:\\Users\\goran\\OneDrive\\FOI_docs\\Radionica Napredno programiranje u Pythonu\\S02\\.ipynb_checkpoints',
#    '',
#    '10.07.2017.  08:21    <DIR>          .',
#    '10.07.2017.  08:21    <DIR>          ..',
#    '10.07.2017.  08:21                72 Untitled-checkpoint.ipynb',
#    '               1 File(s)             72 bytes',
#    '',
#    '     Total Files Listed:',
#    '               2 File(s)          4.034 bytes',
#    '               5 Dir(s)  136.313.028.608 bytes free'],
#   32: [' Volume in drive C has no label.',
#    ' Volume Serial Number is 289C-D677',
#    '',
#    ' Directory of C:\\Users\\goran\\OneDrive\\FOI_docs\\Radionica Napredno programiranje u Pythonu\\S02',
#    '',
#    '10.07.2017.  08:29    <DIR>          .',
#    '10.07.2017.  08:29    <DIR>          ..',
#    '10.07.2017.  08:21    <DIR>          .ipynb_checkpoints',
#    '10.07.2017.  08:29             3.962 Untitled.ipynb',
#    '               1 File(s)          3.962 bytes',
#    '',
#    ' Directory of C:\\Users\\goran\\OneDrive\\FOI_docs\\Radionica Napredno programiranje u Pythonu\\S02\\.ipynb_checkpoints',
#    '',
#    '10.07.2017.  08:21    <DIR>          .',
#    '10.07.2017.  08:21    <DIR>          ..',
#    '10.07.2017.  08:21                72 Untitled-checkpoint.ipynb',
#    '               1 File(s)             72 bytes',
#    '',
#    '     Total Files Listed:',
#    '               2 File(s)          4.034 bytes',
#    '               5 Dir(s)  136.313.008.128 bytes free'],
#   33: 'Untitled.ipynb',
#   39: Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%cmd  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.,
#   40: Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%cmd  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.,
#   41: Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%cmd  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.,
#   64: {...}},
#  '_sh': <module 'IPython.core.shadowns' from 'D:\\Anaconda3\\lib\\site-packages\\IPython\\core\\shadowns.py'>,
#  'd': {1: 'jedan', 'a': 'slovo A'},
#  'd2': {2: '2',
#   4: '4',
#   6: '6',
#   8: '8',
#   10: '10',
#   12: '12',
#   14: '14',
#   16: '16',
#   18: '18',
#   20: '20'},
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x2610fb8d4e0>,
#  'f': <function __main__.f>,
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x000002610FB3C1D0>>,
#  'i': 10,
#  'k': 'a',
#  'notebook_filename': 'Untitled.ipynb',
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x2610fb8d4e0>,
#  'v': 'slovo A',
#  'x': 20,
#  'y': 400}

# %%
globals()
# Out:
# {'In': ['',
#   'd2 = {k:str(k) for k in L}\nd2',
#   'd2 = {k:str(k) for k in L}\nd2',
#   "d = {l:'jedan', 'a':'slovo A'}\n\n# List comprehension\nL = [2*i for i in range(1, 11)]",
#   "d = {'l:'jedan', 'a':'slovo A'}\n\n# List comprehension\nL = [2*i for i in range(1, 11)]",
#   "d = {l:'jedan', a:'slovo A'}\n\n# List comprehension\nL = [2*i for i in range(1, 11)]",
#   'd2 = {k:str(k) for k in L}\nd2',
#   "d = {1:'jedan', a:'slovo A'}\n\n# List comprehension\nL = [2*i for i in range(1, 11)]",
#   "d = {1:'jedan', 'a':'slovo A'}\n\n# List comprehension\nL = [2*i for i in range(1, 11)]",
#   'd2 = {k:str(k) for k in L}\nd2',
#   'd2 = {k:str(k) for k in L}\nd2',
#   'for x in L:\n    y = x ** 2\n    print(y)',
#   'for x in L:\n    y = x ** 2\n    print(y)',
#   'i = 0\nfor x in L:\n    i = i + 1\n    print(i, ".", x)',
#   'i = 0\nfor x in enumerate(L):\n    i = i + 1\n    print(i, ".", x)',
#   'i = 0\nfor i,x in enumerate(L):\n    i = i + 1\n    print(i, ".", x)',
#   'i = 0\nfor i, x in enumerate(L):\n    i = i + 1\n    print(i, ".", x)',
#   'i = 0\nfor i, x in enumerate(L):\n    i = i + 1\n    print(i, ".", x)',
#   'd',
#   'for k in d:\n    print(k)',
#   'for k,v in d:\n    print(k, " ", v)',
#   'for k,d(k() in d:\n    print(k, " ", v)',
#   'for k,d(k) in d:\n    print(k, " ", d(k))',
#   'for k,d[k] in d.values():\n    print(k, " ", d[k]',
#   'for v in d.items():\n    print(v)',
#   'for k, v in d.items():\n    print(k, " ", v)',
#   'for k, v in d.items():\n    print(k, " ", v)',
#   "get_ipython().system('ls')",
#   "get_ipython().system('dir/s')",
#   "# escaping\nget_ipython().system('dir/s')",
#   "# escaping\nL = get_ipython().getoutput('dir/s')",
#   "# escaping\nL = get_ipython().getoutput('dir/s')\nL",
#   "# escaping\nL = get_ipython().getoutput('dir/s')\nL",
#   'notebook_filename = "Untitled.ipynb"\nnotebook_filename',
#   'notebook_filename = "Untitled.ipynb"\nget_ipython().system(\'edit $notebook_filename\')',
#   'notebook_filename = "Untitled.ipynb"\n# !cat $notebook_filename',
#   'notebook_filename = "Untitled.ipynb"\n# !cat $notebook_filename\nget_ipython().system(\'iexplore\')',
#   'notebook_filename = "Untitled.ipynb"\n# !cat $notebook_filename\nget_ipython().system(\'iexplore.exe\')',
#   'notebook_filename = "Untitled.ipynb"\n# !cat $notebook_filename',
#   "get_ipython().magic('lsmagic')",
#   "get_ipython().magic('lsmagic')",
#   "get_ipython().magic('lsmagic ')",
#   'get_ipython().run_cell_magic(\'writefile\', \'"fja.py"\', \'\\ndef f(a, b):\\n    pass\')',
#   'writefile "fja.py"\n\ndef f(a, b):\n    pass',
#   'get_ipython().magic(\'writefile "fja.py"\')\n\ndef f(a, b):\n    pass',
#   'get_ipython().run_cell_magic(\'writefile\', \'"fja.py"\', \'\\ndef f(a, b):\\n    pass\')',
#   '# Spremanje u file\n%%writefile "fja.py"\n\ndef f(a, b):\n    pass',
#   '# Spremanje u file\n\n%%writefile "fja.py"\n\ndef f(a, b):\n    pass',
#   'loadfile "fja.py"',
#   'get_ipython().run_cell_magic(\'writefile\', \'"fja.py"\', \'\\ndef f(a, b):\\n    pass\')',
#   'loadfile "fja.py"',
#   'loadfile "/fja.py"',
#   'loadfile "./fja.py"',
#   'get_ipython().magic(\'loadpy "./fja.py"\')',
#   '# %load "./fja.py"\n\ndef f(a, b):\n    pass',
#   "get_ipython().magic('run hello_world.ipynb')",
#   '# %load "./fja.py"\n\ndef f(a, b):\n    pass',
#   'get_ipython().magic(\'loadpy "fja.py"\')',
#   "get_ipython().magic('run hello_world.ipynb')",
#   "get_ipython().magic('whos ')",
#   'whos\n#Sve varijable koje smo definirali',
#   "get_ipython().magic('whos ')",
#   "get_ipython().run_cell_magic('html', '', '\\nJavascript')",
#   "get_ipython().run_cell_magic('html', '', '\\nJavascript')",
#   'locals()',
#   'locals()',
#   'globals()',
#   'globals()'],
#  'L': [' Volume in drive C has no label.',
#   ' Volume Serial Number is 289C-D677',
#   '',
#   ' Directory of C:\\Users\\goran\\OneDrive\\FOI_docs\\Radionica Napredno programiranje u Pythonu\\S02',
#   '',
#   '10.07.2017.  08:29    <DIR>          .',
#   '10.07.2017.  08:29    <DIR>          ..',
#   '10.07.2017.  08:21    <DIR>          .ipynb_checkpoints',
#   '10.07.2017.  08:29             3.962 Untitled.ipynb',
#   '               1 File(s)          3.962 bytes',
#   '',
#   ' Directory of C:\\Users\\goran\\OneDrive\\FOI_docs\\Radionica Napredno programiranje u Pythonu\\S02\\.ipynb_checkpoints',
#   '',
#   '10.07.2017.  08:21    <DIR>          .',
#   '10.07.2017.  08:21    <DIR>          ..',
#   '10.07.2017.  08:21                72 Untitled-checkpoint.ipynb',
#   '               1 File(s)             72 bytes',
#   '',
#   '     Total Files Listed:',
#   '               2 File(s)          4.034 bytes',
#   '               5 Dir(s)  136.313.008.128 bytes free'],
#  'Out': {9: {2: '2',
#    4: '4',
#    6: '6',
#    8: '8',
#    10: '10',
#    12: '12',
#    14: '14',
#    16: '16',
#    18: '18',
#    20: '20'},
#   10: {2: '2',
#    4: '4',
#    6: '6',
#    8: '8',
#    10: '10',
#    12: '12',
#    14: '14',
#    16: '16',
#    18: '18',
#    20: '20'},
#   18: {1: 'jedan', 'a': 'slovo A'},
#   31: [' Volume in drive C has no label.',
#    ' Volume Serial Number is 289C-D677',
#    '',
#    ' Directory of C:\\Users\\goran\\OneDrive\\FOI_docs\\Radionica Napredno programiranje u Pythonu\\S02',
#    '',
#    '10.07.2017.  08:29    <DIR>          .',
#    '10.07.2017.  08:29    <DIR>          ..',
#    '10.07.2017.  08:21    <DIR>          .ipynb_checkpoints',
#    '10.07.2017.  08:29             3.962 Untitled.ipynb',
#    '               1 File(s)          3.962 bytes',
#    '',
#    ' Directory of C:\\Users\\goran\\OneDrive\\FOI_docs\\Radionica Napredno programiranje u Pythonu\\S02\\.ipynb_checkpoints',
#    '',
#    '10.07.2017.  08:21    <DIR>          .',
#    '10.07.2017.  08:21    <DIR>          ..',
#    '10.07.2017.  08:21                72 Untitled-checkpoint.ipynb',
#    '               1 File(s)             72 bytes',
#    '',
#    '     Total Files Listed:',
#    '               2 File(s)          4.034 bytes',
#    '               5 Dir(s)  136.313.028.608 bytes free'],
#   32: [' Volume in drive C has no label.',
#    ' Volume Serial Number is 289C-D677',
#    '',
#    ' Directory of C:\\Users\\goran\\OneDrive\\FOI_docs\\Radionica Napredno programiranje u Pythonu\\S02',
#    '',
#    '10.07.2017.  08:29    <DIR>          .',
#    '10.07.2017.  08:29    <DIR>          ..',
#    '10.07.2017.  08:21    <DIR>          .ipynb_checkpoints',
#    '10.07.2017.  08:29             3.962 Untitled.ipynb',
#    '               1 File(s)          3.962 bytes',
#    '',
#    ' Directory of C:\\Users\\goran\\OneDrive\\FOI_docs\\Radionica Napredno programiranje u Pythonu\\S02\\.ipynb_checkpoints',
#    '',
#    '10.07.2017.  08:21    <DIR>          .',
#    '10.07.2017.  08:21    <DIR>          ..',
#    '10.07.2017.  08:21                72 Untitled-checkpoint.ipynb',
#    '               1 File(s)             72 bytes',
#    '',
#    '     Total Files Listed:',
#    '               2 File(s)          4.034 bytes',
#    '               5 Dir(s)  136.313.008.128 bytes free'],
#   33: 'Untitled.ipynb',
#   39: Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%cmd  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.,
#   40: Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%cmd  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.,
#   41: Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%cmd  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.,
#   64: {...},
#   65: {...},
#   66: {...}},
#  '_': {...},
#  '_10': {2: '2',
#   4: '4',
#   6: '6',
#   8: '8',
#   10: '10',
#   12: '12',
#   14: '14',
#   16: '16',
#   18: '18',
#   20: '20'},
#  '_18': {1: 'jedan', 'a': 'slovo A'},
#  '_31': [' Volume in drive C has no label.',
#   ' Volume Serial Number is 289C-D677',
#   '',
#   ' Directory of C:\\Users\\goran\\OneDrive\\FOI_docs\\Radionica Napredno programiranje u Pythonu\\S02',
#   '',
#   '10.07.2017.  08:29    <DIR>          .',
#   '10.07.2017.  08:29    <DIR>          ..',
#   '10.07.2017.  08:21    <DIR>          .ipynb_checkpoints',
#   '10.07.2017.  08:29             3.962 Untitled.ipynb',
#   '               1 File(s)          3.962 bytes',
#   '',
#   ' Directory of C:\\Users\\goran\\OneDrive\\FOI_docs\\Radionica Napredno programiranje u Pythonu\\S02\\.ipynb_checkpoints',
#   '',
#   '10.07.2017.  08:21    <DIR>          .',
#   '10.07.2017.  08:21    <DIR>          ..',
#   '10.07.2017.  08:21                72 Untitled-checkpoint.ipynb',
#   '               1 File(s)             72 bytes',
#   '',
#   '     Total Files Listed:',
#   '               2 File(s)          4.034 bytes',
#   '               5 Dir(s)  136.313.028.608 bytes free'],
#  '_32': [' Volume in drive C has no label.',
#   ' Volume Serial Number is 289C-D677',
#   '',
#   ' Directory of C:\\Users\\goran\\OneDrive\\FOI_docs\\Radionica Napredno programiranje u Pythonu\\S02',
#   '',
#   '10.07.2017.  08:29    <DIR>          .',
#   '10.07.2017.  08:29    <DIR>          ..',
#   '10.07.2017.  08:21    <DIR>          .ipynb_checkpoints',
#   '10.07.2017.  08:29             3.962 Untitled.ipynb',
#   '               1 File(s)          3.962 bytes',
#   '',
#   ' Directory of C:\\Users\\goran\\OneDrive\\FOI_docs\\Radionica Napredno programiranje u Pythonu\\S02\\.ipynb_checkpoints',
#   '',
#   '10.07.2017.  08:21    <DIR>          .',
#   '10.07.2017.  08:21    <DIR>          ..',
#   '10.07.2017.  08:21                72 Untitled-checkpoint.ipynb',
#   '               1 File(s)             72 bytes',
#   '',
#   '     Total Files Listed:',
#   '               2 File(s)          4.034 bytes',
#   '               5 Dir(s)  136.313.008.128 bytes free'],
#  '_33': 'Untitled.ipynb',
#  '_39': Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%cmd  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.,
#  '_40': Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%cmd  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.,
#  '_41': Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%cmd  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.,
#  '_64': {...},
#  '_65': {...},
#  '_66': {...},
#  '_9': {2: '2',
#   4: '4',
#   6: '6',
#   8: '8',
#   10: '10',
#   12: '12',
#   14: '14',
#   16: '16',
#   18: '18',
#   20: '20'},
#  '__': {...},
#  '___': {...},
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__loader__': None,
#  '__name__': '__main__',
#  '__package__': None,
#  '__spec__': None,
#  '_dh': ['C:\\Users\\goran\\OneDrive\\FOI_docs\\Radionica Napredno programiranje u Pythonu\\S02'],
#  '_exit_code': 1,
#  '_i': 'globals()',
#  '_i1': 'd2 = {k:str(k) for k in L}\nd2',
#  '_i10': 'd2 = {k:str(k) for k in L}\nd2',
#  '_i11': 'for x in L:\n    y = x ** 2\n    print(y)',
#  '_i12': 'for x in L:\n    y = x ** 2\n    print(y)',
#  '_i13': 'i = 0\nfor x in L:\n    i = i + 1\n    print(i, ".", x)',
#  '_i14': 'i = 0\nfor x in enumerate(L):\n    i = i + 1\n    print(i, ".", x)',
#  '_i15': 'i = 0\nfor i,x in enumerate(L):\n    i = i + 1\n    print(i, ".", x)',
#  '_i16': 'i = 0\nfor i, x in enumerate(L):\n    i = i + 1\n    print(i, ".", x)',
#  '_i17': 'i = 0\nfor i, x in enumerate(L):\n    i = i + 1\n    print(i, ".", x)',
#  '_i18': 'd',
#  '_i19': 'for k in d:\n    print(k)',
#  '_i2': 'd2 = {k:str(k) for k in L}\nd2',
#  '_i20': 'for k,v in d:\n    print(k, " ", v)',
#  '_i21': 'for k,d(k() in d:\n    print(k, " ", v)',
#  '_i22': 'for k,d(k) in d:\n    print(k, " ", d(k))',
#  '_i23': 'for k,d[k] in d.values():\n    print(k, " ", d[k]',
#  '_i24': 'for v in d.items():\n    print(v)',
#  '_i25': 'for k, v in d.items():\n    print(k, " ", v)',
#  '_i26': 'for k, v in d.items():\n    print(k, " ", v)',
#  '_i27': '!ls',
#  '_i28': '!dir/s',
#  '_i29': '# escaping\n!dir/s',
#  '_i3': "d = {l:'jedan', 'a':'slovo A'}\n\n# List comprehension\nL = [2*i for i in range(1, 11)]",
#  '_i30': '# escaping\nL = !dir/s',
#  '_i31': '# escaping\nL = !dir/s\nL',
#  '_i32': '# escaping\nL = !dir/s\nL',
#  '_i33': 'notebook_filename = "Untitled.ipynb"\nnotebook_filename',
#  '_i34': 'notebook_filename = "Untitled.ipynb"\n!edit $notebook_filename',
#  '_i35': 'notebook_filename = "Untitled.ipynb"\n# !cat $notebook_filename',
#  '_i36': 'notebook_filename = "Untitled.ipynb"\n# !cat $notebook_filename\n!iexplore',
#  '_i37': 'notebook_filename = "Untitled.ipynb"\n# !cat $notebook_filename\n!iexplore.exe',
#  '_i38': 'notebook_filename = "Untitled.ipynb"\n# !cat $notebook_filename',
#  '_i39': '%lsmagic',
#  '_i4': "d = {'l:'jedan', 'a':'slovo A'}\n\n# List comprehension\nL = [2*i for i in range(1, 11)]",
#  '_i40': '%lsmagic',
#  '_i41': 'lsmagic',
#  '_i42': '%%writefile "fja.py"\n\ndef f(a, b):\n    pass',
#  '_i43': 'writefile "fja.py"\n\ndef f(a, b):\n    pass',
#  '_i44': '%writefile "fja.py"\n\ndef f(a, b):\n    pass',
#  '_i45': '%%writefile "fja.py"\n\ndef f(a, b):\n    pass',
#  '_i46': '# Spremanje u file\n%%writefile "fja.py"\n\ndef f(a, b):\n    pass',
#  '_i47': '# Spremanje u file\n\n%%writefile "fja.py"\n\ndef f(a, b):\n    pass',
#  '_i48': 'loadfile "fja.py"',
#  '_i49': '%%writefile "fja.py"\n\ndef f(a, b):\n    pass',
#  '_i5': "d = {l:'jedan', a:'slovo A'}\n\n# List comprehension\nL = [2*i for i in range(1, 11)]",
#  '_i50': 'loadfile "fja.py"',
#  '_i51': 'loadfile "/fja.py"',
#  '_i52': 'loadfile "./fja.py"',
#  '_i53': 'loadpy "./fja.py"',
#  '_i54': '# %load "./fja.py"\n\ndef f(a, b):\n    pass',
#  '_i55': 'run hello_world.ipynb',
#  '_i56': '# %load "./fja.py"\n\ndef f(a, b):\n    pass',
#  '_i57': 'loadpy "fja.py"',
#  '_i58': 'run hello_world.ipynb',
#  '_i59': 'whos',
#  '_i6': 'd2 = {k:str(k) for k in L}\nd2',
#  '_i60': 'whos\n#Sve varijable koje smo definirali',
#  '_i61': 'whos',
#  '_i62': '%%html\n\nJavascript',
#  '_i63': '%%html\n\nJavascript',
#  '_i64': 'locals()',
#  '_i65': 'locals()',
#  '_i66': 'globals()',
#  '_i67': 'globals()',
#  '_i7': "d = {1:'jedan', a:'slovo A'}\n\n# List comprehension\nL = [2*i for i in range(1, 11)]",
#  '_i8': "d = {1:'jedan', 'a':'slovo A'}\n\n# List comprehension\nL = [2*i for i in range(1, 11)]",
#  '_i9': 'd2 = {k:str(k) for k in L}\nd2',
#  '_ih': ['',
#   'd2 = {k:str(k) for k in L}\nd2',
#   'd2 = {k:str(k) for k in L}\nd2',
#   "d = {l:'jedan', 'a':'slovo A'}\n\n# List comprehension\nL = [2*i for i in range(1, 11)]",
#   "d = {'l:'jedan', 'a':'slovo A'}\n\n# List comprehension\nL = [2*i for i in range(1, 11)]",
#   "d = {l:'jedan', a:'slovo A'}\n\n# List comprehension\nL = [2*i for i in range(1, 11)]",
#   'd2 = {k:str(k) for k in L}\nd2',
#   "d = {1:'jedan', a:'slovo A'}\n\n# List comprehension\nL = [2*i for i in range(1, 11)]",
#   "d = {1:'jedan', 'a':'slovo A'}\n\n# List comprehension\nL = [2*i for i in range(1, 11)]",
#   'd2 = {k:str(k) for k in L}\nd2',
#   'd2 = {k:str(k) for k in L}\nd2',
#   'for x in L:\n    y = x ** 2\n    print(y)',
#   'for x in L:\n    y = x ** 2\n    print(y)',
#   'i = 0\nfor x in L:\n    i = i + 1\n    print(i, ".", x)',
#   'i = 0\nfor x in enumerate(L):\n    i = i + 1\n    print(i, ".", x)',
#   'i = 0\nfor i,x in enumerate(L):\n    i = i + 1\n    print(i, ".", x)',
#   'i = 0\nfor i, x in enumerate(L):\n    i = i + 1\n    print(i, ".", x)',
#   'i = 0\nfor i, x in enumerate(L):\n    i = i + 1\n    print(i, ".", x)',
#   'd',
#   'for k in d:\n    print(k)',
#   'for k,v in d:\n    print(k, " ", v)',
#   'for k,d(k() in d:\n    print(k, " ", v)',
#   'for k,d(k) in d:\n    print(k, " ", d(k))',
#   'for k,d[k] in d.values():\n    print(k, " ", d[k]',
#   'for v in d.items():\n    print(v)',
#   'for k, v in d.items():\n    print(k, " ", v)',
#   'for k, v in d.items():\n    print(k, " ", v)',
#   "get_ipython().system('ls')",
#   "get_ipython().system('dir/s')",
#   "# escaping\nget_ipython().system('dir/s')",
#   "# escaping\nL = get_ipython().getoutput('dir/s')",
#   "# escaping\nL = get_ipython().getoutput('dir/s')\nL",
#   "# escaping\nL = get_ipython().getoutput('dir/s')\nL",
#   'notebook_filename = "Untitled.ipynb"\nnotebook_filename',
#   'notebook_filename = "Untitled.ipynb"\nget_ipython().system(\'edit $notebook_filename\')',
#   'notebook_filename = "Untitled.ipynb"\n# !cat $notebook_filename',
#   'notebook_filename = "Untitled.ipynb"\n# !cat $notebook_filename\nget_ipython().system(\'iexplore\')',
#   'notebook_filename = "Untitled.ipynb"\n# !cat $notebook_filename\nget_ipython().system(\'iexplore.exe\')',
#   'notebook_filename = "Untitled.ipynb"\n# !cat $notebook_filename',
#   "get_ipython().magic('lsmagic')",
#   "get_ipython().magic('lsmagic')",
#   "get_ipython().magic('lsmagic ')",
#   'get_ipython().run_cell_magic(\'writefile\', \'"fja.py"\', \'\\ndef f(a, b):\\n    pass\')',
#   'writefile "fja.py"\n\ndef f(a, b):\n    pass',
#   'get_ipython().magic(\'writefile "fja.py"\')\n\ndef f(a, b):\n    pass',
#   'get_ipython().run_cell_magic(\'writefile\', \'"fja.py"\', \'\\ndef f(a, b):\\n    pass\')',
#   '# Spremanje u file\n%%writefile "fja.py"\n\ndef f(a, b):\n    pass',
#   '# Spremanje u file\n\n%%writefile "fja.py"\n\ndef f(a, b):\n    pass',
#   'loadfile "fja.py"',
#   'get_ipython().run_cell_magic(\'writefile\', \'"fja.py"\', \'\\ndef f(a, b):\\n    pass\')',
#   'loadfile "fja.py"',
#   'loadfile "/fja.py"',
#   'loadfile "./fja.py"',
#   'get_ipython().magic(\'loadpy "./fja.py"\')',
#   '# %load "./fja.py"\n\ndef f(a, b):\n    pass',
#   "get_ipython().magic('run hello_world.ipynb')",
#   '# %load "./fja.py"\n\ndef f(a, b):\n    pass',
#   'get_ipython().magic(\'loadpy "fja.py"\')',
#   "get_ipython().magic('run hello_world.ipynb')",
#   "get_ipython().magic('whos ')",
#   'whos\n#Sve varijable koje smo definirali',
#   "get_ipython().magic('whos ')",
#   "get_ipython().run_cell_magic('html', '', '\\nJavascript')",
#   "get_ipython().run_cell_magic('html', '', '\\nJavascript')",
#   'locals()',
#   'locals()',
#   'globals()',
#   'globals()'],
#  '_ii': 'locals()',
#  '_iii': 'locals()',
#  '_oh': {9: {2: '2',
#    4: '4',
#    6: '6',
#    8: '8',
#    10: '10',
#    12: '12',
#    14: '14',
#    16: '16',
#    18: '18',
#    20: '20'},
#   10: {2: '2',
#    4: '4',
#    6: '6',
#    8: '8',
#    10: '10',
#    12: '12',
#    14: '14',
#    16: '16',
#    18: '18',
#    20: '20'},
#   18: {1: 'jedan', 'a': 'slovo A'},
#   31: [' Volume in drive C has no label.',
#    ' Volume Serial Number is 289C-D677',
#    '',
#    ' Directory of C:\\Users\\goran\\OneDrive\\FOI_docs\\Radionica Napredno programiranje u Pythonu\\S02',
#    '',
#    '10.07.2017.  08:29    <DIR>          .',
#    '10.07.2017.  08:29    <DIR>          ..',
#    '10.07.2017.  08:21    <DIR>          .ipynb_checkpoints',
#    '10.07.2017.  08:29             3.962 Untitled.ipynb',
#    '               1 File(s)          3.962 bytes',
#    '',
#    ' Directory of C:\\Users\\goran\\OneDrive\\FOI_docs\\Radionica Napredno programiranje u Pythonu\\S02\\.ipynb_checkpoints',
#    '',
#    '10.07.2017.  08:21    <DIR>          .',
#    '10.07.2017.  08:21    <DIR>          ..',
#    '10.07.2017.  08:21                72 Untitled-checkpoint.ipynb',
#    '               1 File(s)             72 bytes',
#    '',
#    '     Total Files Listed:',
#    '               2 File(s)          4.034 bytes',
#    '               5 Dir(s)  136.313.028.608 bytes free'],
#   32: [' Volume in drive C has no label.',
#    ' Volume Serial Number is 289C-D677',
#    '',
#    ' Directory of C:\\Users\\goran\\OneDrive\\FOI_docs\\Radionica Napredno programiranje u Pythonu\\S02',
#    '',
#    '10.07.2017.  08:29    <DIR>          .',
#    '10.07.2017.  08:29    <DIR>          ..',
#    '10.07.2017.  08:21    <DIR>          .ipynb_checkpoints',
#    '10.07.2017.  08:29             3.962 Untitled.ipynb',
#    '               1 File(s)          3.962 bytes',
#    '',
#    ' Directory of C:\\Users\\goran\\OneDrive\\FOI_docs\\Radionica Napredno programiranje u Pythonu\\S02\\.ipynb_checkpoints',
#    '',
#    '10.07.2017.  08:21    <DIR>          .',
#    '10.07.2017.  08:21    <DIR>          ..',
#    '10.07.2017.  08:21                72 Untitled-checkpoint.ipynb',
#    '               1 File(s)             72 bytes',
#    '',
#    '     Total Files Listed:',
#    '               2 File(s)          4.034 bytes',
#    '               5 Dir(s)  136.313.008.128 bytes free'],
#   33: 'Untitled.ipynb',
#   39: Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%cmd  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.,
#   40: Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%cmd  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.,
#   41: Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%cmd  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.,
#   64: {...},
#   65: {...},
#   66: {...}},
#  '_sh': <module 'IPython.core.shadowns' from 'D:\\Anaconda3\\lib\\site-packages\\IPython\\core\\shadowns.py'>,
#  'd': {1: 'jedan', 'a': 'slovo A'},
#  'd2': {2: '2',
#   4: '4',
#   6: '6',
#   8: '8',
#   10: '10',
#   12: '12',
#   14: '14',
#   16: '16',
#   18: '18',
#   20: '20'},
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x2610fb8d4e0>,
#  'f': <function __main__.f>,
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x000002610FB3C1D0>>,
#  'i': 10,
#  'k': 'a',
#  'notebook_filename': 'Untitled.ipynb',
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x2610fb8d4e0>,
#  'v': 'slovo A',
#  'x': 20,
#  'y': 400}
