# %% [markdown]
# # Naslov

# %% [markdown]
# ## Podnaslov
#
# Lorem ipsum dolor sit amet, consectetur adipiscing elit. Sed sit amet mauris non diam mattis fermentum. Ut at gravida nibh. Pellentesque vulputate arcu quis ipsum sollicitudin, a venenatis massa lacinia. Quisque id libero a velit fringilla lobortis id eu diam. Pellentesque dapibus neque at congue blandit. Etiam orci augue, venenatis vitae libero at, auctor finibus sem. Duis nec consequat purus. Curabitur semper tincidunt placerat.
#
# In dictum euismod imperdiet. Lorem ipsum dolor sit amet, consectetur adipiscing elit. Suspendisse lacinia volutpat congue. Fusce tristique tellus dapibus neque accumsan blandit. Vestibulum volutpat tortor nec dignissim dictum. Maecenas sagittis mi eget dictum tempor. Phasellus eu tortor sed justo dignissim malesuada at vitae justo. Vivamus urna nulla, facilisis non massa pretium, cursus ultrices libero.
#
# Random lista ide ovdje:
# * prva stavka
# * stavka 2
# * treća stavka
# * četvrta stavka

# %% [markdown]
# ## Neki drugi podnaslov
#
# Phasellus eros diam, vulputate tempor fermentum pulvinar, elementum non justo. In sit amet augue eget sapien finibus lobortis ac non lorem. Etiam eu molestie magna. Integer placerat condimentum arcu eget pharetra. Etiam maximus arcu lectus. Pellentesque id efficitur dui, in molestie erat. Sed ut tellus aliquam, sagittis diam non, faucibus nunc. Duis a luctus dolor. Aenean dolor arcu, lobortis vitae lacus eu, elementum rhoncus odio. Aenean ullamcorper porta purus vel porta. Duis non condimentum arcu, nec condimentum ligula. Ut arcu nibh, fermentum vitae condimentum ut, fringilla sed augue.
#
# Ovo je još jedna random lista:
# 1. Neka stavka
#     * Podstavka prva
#     * Podstavka druga
# 2. Neka druga stavka
# 3. Neka stavka broj tri
#     + još malo lista
#     - sad malo i s minusom

# %% [markdown]
# # Drugi veliki naslov

# %% [markdown]
# <span style="font-size: 20px">Ovaj dio će sadržavati malo $\LaTeX$-a.</span>
#
# Također će sadržavat i mrvicu $inline\ \Large{\texttt{HTML}}$-a.
#
# Ok... back to _lipsum_...
#
# Cras ornare tellus lobortis semper posuere. Duis velit nisl, suscipit pellentesque massa ut, vehicula porttitor ante. In turpis sem, mattis porttitor tristique nec, commodo eu nulla. Proin placerat sit amet turpis quis laoreet. Vestibulum ante ipsum primis in faucibus orci luctus et ultrices posuere cubilia Curae; Donec varius nec lacus et viverra. Nulla pulvinar gravida tristique. Nulla tellus purus, porttitor vitae purus et, convallis gravida mi. Phasellus turpis ipsum, sodales eu dignissim sit amet, dignissim ut mauris. Curabitur iaculis commodo dolor. Aenean nisl metus, condimentum non erat vitae, sodales rutrum nisl.

# %% [markdown]
# ## Podnaslov pod drugim naslovom
#
# Phasellus ipsum mi, congue quis volutpat at, pretium ut enim. Proin auctor nisi at nibh porttitor, in eleifend urna vulputate. Sed vestibulum dignissim lectus, sed cursus enim pretium nec. Donec dignissim eros vel ipsum ornare, blandit auctor lorem facilisis. Integer eu feugiat purus. Praesent varius, libero id posuere tincidunt, arcu elit congue urna, a tincidunt justo nibh iaculis eros. Etiam vel tortor et purus vehicula molestie id id magna.
#
# Aliquam blandit vehicula diam a ornare. Aliquam eget justo turpis. Sed eleifend massa vel cursus pharetra. Curabitur enim libero, efficitur vel odio eget, euismod lobortis nunc. Ut nibh arcu, accumsan quis massa et, imperdiet vehicula massa. Ut nunc justo, viverra vitae risus id, molestie sollicitudin libero. Aenean placerat, nisl eget pretium vestibulum, dolor nisl porttitor lorem, vel interdum orci diam ac est. Vestibulum ante ipsum primis in faucibus orci luctus et ultrices posuere cubilia Curae; Etiam porttitor laoreet scelerisque.
#
# Cras placerat vel lorem nec condimentum. Quisque consequat arcu ac tellus condimentum, ac feugiat nulla tincidunt. Donec et magna venenatis, ornare elit sit amet, aliquam libero. Suspendisse ut suscipit arcu. Donec sit amet ornare neque, in iaculis libero. Maecenas posuere lacus id luctus posuere. Cras bibendum nisl ac congue bibendum. Donec porta sem quis libero faucibus dictum. Vestibulum non justo pulvinar, elementum mauris eu, aliquam metus. Phasellus congue tempus nisi, sed auctor neque tincidunt eget. Aliquam vitae est consequat ipsum molestie suscipit. Suspendisse congue fringilla mauris quis lobortis. In hac habitasse platea dictumst.

# %% [markdown]
# # Python primjeri

# %% [markdown]
# ## Naravno da syntax highlighting radi 😁
# ```python
# d = {1:'jedan', 'a':'slovo A'}
#
# # List comprehension
# L = [2*i for i in range(1, 11)]
# ```
#
# ### CSS... will it work?
# ```css
# header {
#     font-family: Roboto, sans-serif;
#     font-weight: 300;
#     font-size: 32px;
#     margin: auto;
#     color: #ff0abe;
# }
# ```
# `
# Of
#   course
#     i
#     t
#   will
# `
